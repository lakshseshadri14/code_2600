# %% [markdown]
# ## Lab 1: Data in Python
#
# The data for this activity can be downloaded here (under "Data Sets"): https://www.statlearning.com/resources-python

# %% [markdown]
# As a first step, create a folder in this location called "data" and drop the Credit.csv file in that location.
#
# If you open the ".gitignore" file, you'll notice that one of the entries is "data" so that your data files will not be shared on GitHub.

# %%
import pandas as pd
import numpy as np
Credit = pd.read_csv('data/Credit.csv') 
Credit
# Out:
#       Income  Limit  Rating  Cards  Age  Education  Own Student Married  \
# 0     14.891   3606     283      2   34         11   No      No     Yes
# 1    106.025   6645     483      3   82         15  Yes     Yes     Yes
# 2    104.593   7075     514      4   71         11   No      No      No
# 3    148.924   9504     681      3   36         11  Yes      No      No
# 4     55.882   4897     357      2   68         16   No      No     Yes
# ..       ...    ...     ...    ...  ...        ...  ...     ...     ...
# 395   12.096   4100     307      3   32         13   No      No     Yes
# 396   13.364   3838     296      5   65         17   No      No      No
# 397   57.872   4171     321      5   67         12  Yes      No     Yes
# 398   37.728   2525     192      1   44         13   No      No     Yes
# 399   18.701   5524     415      5   64          7  Yes      No      No
#
#     Region  Balance
# 0    South      333
# 1     West      903
# 2     West      580
# 3     West      964
# 4    South      331
# ..     ...      ...
# 395  South      560
# 396   East      480
# 397  South      138
# 398  South        0
# 399   West      966
#
# [400 rows x 11 columns]

# %% [markdown]
# ### What are the feature names?

# %%
#Income, Limit, Rating, Cards, Age, Education, Own, Student, Married, Region, Balance

# %% [markdown]
# ### What are the data types of the feature values (i.e., numeric, categorical)

# %%
#Income, Limit, Rating, Cards, Age, Education, Balance - Quantitative/numeric
#wn, Student, Married, Region - Categorical

# %% [markdown]
# ### Find the mean, median, and mode of the feature "Age."

# %%
# mean
Credit = pd.read_csv('data/Credit.csv')
mean = Credit['Age'].mean()
print(mean)
# Out:
# 55.6675

# %%
# median

median = Credit['Age'].median()
print(median)
# Out:
# 56.0

# %%
# mode
Credit = pd.read_csv('data/Credit.csv')
mode = Credit['Age'].mode()
print(mode)
# Out:
# 0    44
# 1    66
# Name: Age, dtype: int64

# %% [markdown]
# ### Create a subset of Credit that only contains the columns Age, Region, and Income. Call it "Subset."

# %%
Subset = Credit[['Age', 'Region', 'Income']]
print(Subset.head(len(Credit)))
# Out:
#      Age Region   Income
# 0     34  South   14.891
# 1     82   West  106.025
# 2     71   West  104.593
# 3     36   West  148.924
# 4     68  South   55.882
# ..   ...    ...      ...
# 395   32  South   12.096
# 396   65   East   13.364
# 397   67  South   57.872
# 398   44  South   37.728
# 399   64   West   18.701
#
# [400 rows x 3 columns]

# %% [markdown]
# ### From this subset, create two partitions:
# - One that contains records for Ages below 50, and one that contains Ages 50+
# - Call them "Younger" and "Older"

# %%
younger = Subset[Subset['Age']<50]
print(younger)
# Out:
#      Age Region   Income
# 0     34  South   14.891
# 3     36   West  148.924
# 6     37   East   20.996
# 9     41   East   71.061
# 10    30  South   63.095
# ..   ...    ...      ...
# 391   43  South   73.327
# 392   24   West   25.974
# 394   40  South   49.794
# 395   32  South   12.096
# 398   44  South   37.728
#
# [161 rows x 3 columns]

# %%
older = Subset[Subset['Age']>=50]
print(older)
# Out:
#      Age Region   Income
# 1     82   West  106.025
# 2     71   West  104.593
# 4     68  South   55.882
# 5     77  South   80.180
# 7     87   West   71.408
# ..   ...    ...      ...
# 390   81   West  135.118
# 393   65   East   17.316
# 396   65   East   13.364
# 397   67  South   57.872
# 399   64   West   18.701
#
# [239 rows x 3 columns]

# %% [markdown]
# ### Use these partitions to compare the mean and median Income for each age group (less than 50 vs. 50+)

# %%
# mean of younger
#younger = Subset[Subset['Age'] <= 50]
mean_younger = younger['Income'].mean()
print(mean_younger)
# Out:
# 41.65203726708074

# %%
# mean of older
#older = Subset[Subset['Age'] > 50]
mean_older = older['Income'].mean()
print(mean_older)
# Out:
# 47.6216569037657

# %%
# median of younger
#Younger = Subset[Subset['Age']<50]
print(Younger['Age'].median())
# Out:
# 40.0

# %%
# median of older
#Older = Subset[Subset['Age']>=50]
print(Older['Age'].median())
# Out:
# 68.0

# %% [markdown]
# ### What does the difference between mean and median suggest about the distribution of income?

# %% [markdown]
# Its basically tells us that the data is not skewed and is almost symmetric

# %% [markdown]
# ### What are the possible values for Region?

# %%
#There are 4 possible values: North, South, East, West

# %% [markdown]
# ### Use the value_counts method to build a frequency table for the possible values of Region.

# %%
freq_table = Subset['Region'].value_counts()
print(freq_table)
# Out:
# Region
# South    199
# West     102
# East      99
# Name: count, dtype: int64

# %% [markdown]
# ### Compare the average income for students vs. non-students.

# %%
Subset2 = Credit[['Student', 'Income']]
print(Subset2.head(len(Credit)))
# Out:
#     Student   Income
# 0        No   14.891
# 1       Yes  106.025
# 2        No  104.593
# 3        No  148.924
# 4        No   55.882
# ..      ...      ...
# 395      No   12.096
# 396      No   13.364
# 397      No   57.872
# 398      No   37.728
# 399      No   18.701
#
# [400 rows x 2 columns]

# %%
is_student = Subset2[Subset2['Student'] == "Yes"]
avg_student_income = is_student['Income'].mean()
print(avg_student_income)
# Out:
# 47.29205

# %%
is_not_student = Subset2[Subset2['Student'] == "No"]
avg_income = is_not_student['Income'].mean()
print(avg_income)
# Out:
# 44.988533333333336

# %% [markdown]
# Often, banks will use a variable called _utilization_ to assess credit risk.
# Utilization is the ratio of balance to limit (i.e., what % of the credit limit is being used?)
# ### Add a feature to the Credit dataset to measure utilization

# %%
Credit['Utilization'] = Credit['Balance']/Credit['Limit']
print(Credit['Utilization'])
# Out:
# 0      0.092346
# 1      0.135892
# 2      0.081979
# 3      0.101431
# 4      0.067592
#          ...
# 395    0.136585
# 396    0.125065
# 397    0.033086
# 398    0.000000
# 399    0.174873
# Name: Utilization, Length: 400, dtype: float64

# %% [markdown]
# ### What is the maximum utilization value in this set?

# %%
max_percent = Credit['Utilization'].max()
print(max_percent)
# Out:
# 0.27693008426326576
